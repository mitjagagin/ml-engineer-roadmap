# %% [markdown]
# # Python basics (portfolio)
#
# ## Goal
# Закрепить базовые конструкции Python, которые постоянно нужны в ML/ML Engineering: коллекции, циклы, функции, работа со строками.
#
# ## Contents
# - list / dict / loops
# - простые вычисления (sum, filters)
# - частоты слов
# - маленькая практическая функция (метрики classification)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\gagindv\AppData\Local\miniconda3\envs\ml\python.exe

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = [x for x in nums if x % 2 == 0]
evens
# Out:
# [2, 4, 6]

# %%
sum(x for x in nums if x % 3 == 0)
# Out:
# 9

# %%
s = "ml engineer engineer python ml"
freq = {}
for w in s.split():
    freq[w] = freq.get(w, 0) + 1
freq
# Out:
# {'ml': 2, 'engineer': 2, 'python': 1}

# %%
def precision_recall_f1(tp, fp, fn):
    """
    tp: true positives
    fp: false positives
    fn: false negatives

    Возвращает (precision, recall, f1).
    Это базовые метрики в задачах классификации.
    """
    precision = tp / (tp + fp) if (tp + fp) else 0.0
    recall = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0.0
    return precision, recall, f1

precision_recall_f1(tp=80, fp=10, fn=20)
# Out:
# (0.8888888888888888, 0.8, 0.8421052631578948)

# %% [markdown]
# ## Summary
# - Закрепил: list/dict/loops/functions, работа со строками.
# - Следующий шаг: табличные данные (pandas) и базовый ML pipeline (sklearn).
